# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading and inspection

# %%
#import and read
#import and read the datbase store in a variable caleed movies

# %%
movies=pd.read_excel("C:\\Users\\Win\Desktop\\IMDB_Movies.xlsx")
orgdata=movies
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     165.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# # Inspect The dataframe

# %%
movies.shape
# Out:
# (5043, 28)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# # Cleaning the data

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     165.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# gross                        884
# budget                       492
# aspect_ratio                 329
# content_rating               303
# plot_keywords                153
# title_year                   108
# director_name                104
# director_facebook_likes      104
# num_critic_for_reviews        50
# actor_3_name                  23
# actor_3_facebook_likes        23
# num_user_for_reviews          20
# color                         19
# duration                      15
# facenumber_in_poster          13
# actor_2_name                  13
# actor_2_facebook_likes        13
# language                      12
# actor_1_name                   7
# actor_1_facebook_likes         7
# country                        5
# cast_total_facebook_likes      0
# num_voted_users                0
# movie_title                    0
# movie_imdb_link                0
# genres                         0
# imdb_score                     0
# movie_facebook_likes           0
# dtype: int64

# %%
movies.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 279     15
# 4       13
# 4945    11
# 2241    11
# 2342    10
#         ..
# 1703     0
# 1702     0
# 1701     0
# 1700     0
# 5042     0
# Length: 5043, dtype: int64

# %%
movies.isnull().sum(axis=0).sort_values(ascending=False)/len(movies)*100
# Out:
# gross                        17.529248
# budget                        9.756098
# aspect_ratio                  6.523895
# content_rating                6.008328
# plot_keywords                 3.033908
# title_year                    2.141582
# director_name                 2.062265
# director_facebook_likes       2.062265
# num_critic_for_reviews        0.991473
# actor_3_name                  0.456078
# actor_3_facebook_likes        0.456078
# num_user_for_reviews          0.396589
# color                         0.376760
# duration                      0.297442
# facenumber_in_poster          0.257783
# actor_2_name                  0.257783
# actor_2_facebook_likes        0.257783
# language                      0.237954
# actor_1_name                  0.138806
# actor_1_facebook_likes        0.138806
# country                       0.099147
# cast_total_facebook_likes     0.000000
# num_voted_users               0.000000
# movie_title                   0.000000
# ...

# %% [markdown]
# # Drop unnecessary column

# %% [markdown]
# #Some columns are not required thats why i'm removing some columns i want movies with respect to ratings, gross collection,popularity of movies

# %%
movies.drop(["color","duration","director_facebook_likes","actor_3_facebook_likes","actor_2_name","actor_1_facebook_likes","country","content_rating","actor_2_facebook_likes"],axis=1,inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
round(movies.isnull().sum().sort_values(ascending=False)/len(movies)*100,2)
# Out:
# gross                        17.53
# budget                        9.76
# aspect_ratio                  6.52
# plot_keywords                 3.03
# title_year                    2.14
# director_name                 2.06
# num_critic_for_reviews        0.99
# actor_3_name                  0.46
# num_user_for_reviews          0.40
# facenumber_in_poster          0.26
# language                      0.24
# actor_1_name                  0.14
# cast_total_facebook_likes     0.00
# movie_imdb_link               0.00
# num_voted_users               0.00
# movie_title                   0.00
# imdb_score                    0.00
# genres                        0.00
# movie_facebook_likes          0.00
# dtype: float64

# %% [markdown]
# # Drop unnecessary column with high  null percentages

# %%
movies[movies["gross"].notnull()]
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
#movies=pd.set_option()

# %%
round(movies.isnull().sum(axis=1).sort_values(ascending=False) > 5).sum()
# Out:
# 15.0

# %%
[movies.isnull().sum(axis=1).sort_values(ascending=False) <= 5]
# Out:
# [279     False
#  2342    False
#  4       False
#  2870    False
#  2241    False
#          ...
#  1703     True
#  1702     True
#  1701     True
#  1700     True
#  5042     True
#  Length: 5043, dtype: bool]

# %%
movies= movies[movies["gross"].notnull()]
movies= movies[movies["budget"].notnull()]

# %%
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# # SUBSTACK 2.5: Fill NaN Values

# %%
# you might notice that language column has some NAN values Here on inspection you will see that it is safe to replace all the missing values with 'English'

# %%
movies.groupby('language').language.count().sort_values(ascending=False)
# Out:
# language
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Portuguese       5
# Korean           5
# Norwegian        4
# Dutch            3
# Persian          3
# Danish           3
# Hebrew           3
# Thai             3
# Indonesian       2
# Aboriginal       2
# Dari             2
# Czech            1
# Vietnamese       1
# Aramaic          1
# Telugu           1
# Swedish          1
# Bosnian          1
# Russian          1
# Romanian         1
# Arabic           1
# Icelandic        1
# Dzongkha         1
# None             1
# Mongolian        1
# Maya             1
# Filipino         1
# Hungarian        1
# Kazakh           1
# Zulu             1
# Name: language, dtype: int64

# %%
movies.language.describe()
# Out:
# count        3888
# unique         38
# top       English
# freq         3707
# Name: language, dtype: object

# %%
movies.language = movies.language.fillna('English')

# %%
movies.groupby('language').language.count().sort_values(ascending=False)
# Out:
# language
# English       3710
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Portuguese       5
# Korean           5
# Norwegian        4
# Dutch            3
# Persian          3
# Danish           3
# Hebrew           3
# Thai             3
# Indonesian       2
# Aboriginal       2
# Dari             2
# Czech            1
# Vietnamese       1
# Aramaic          1
# Telugu           1
# Swedish          1
# Bosnian          1
# Russian          1
# Romanian         1
# Arabic           1
# Icelandic        1
# Dzongkha         1
# None             1
# Mongolian        1
# Maya             1
# Filipino         1
# Hungarian        1
# Kazakh           1
# Zulu             1
# Name: language, dtype: int64

# %%
round(movies.isnull().sum().sort_values(ascending=False)/len(movies)*100,2)
# Out:
# aspect_ratio                 1.93
# plot_keywords                0.80
# actor_3_name                 0.26
# facenumber_in_poster         0.15
# actor_1_name                 0.08
# num_critic_for_reviews       0.03
# num_user_for_reviews         0.00
# imdb_score                   0.00
# title_year                   0.00
# budget                       0.00
# language                     0.00
# director_name                0.00
# movie_imdb_link              0.00
# cast_total_facebook_likes    0.00
# num_voted_users              0.00
# movie_title                  0.00
# genres                       0.00
# gross                        0.00
# movie_facebook_likes         0.00
# dtype: float64

# %% [markdown]
# # Substack 2.6: Check the number of retained rows

# %%
# you might know that the two columns viz.num_critic_for_reviews and actor_1_name have small percentage of NaN valuesleft. you can let these columns as it is for now.check the number and percentage of the retained rows retained after completing the task above

# %%
len(movies)
# Out:
# 3891

# %%
len(movies)/len(orgdata)*100
# Out:
# 77.15645449137418

# %%
#checkpoint 1: You might have noticed that we still have around 77% of the rows

# %% [markdown]
# # TASK 3: Data analysis

# %%
#Subtask 3.1: Change the unit of columns 
#convert the unit of the budget and gross columns from $ to million

# %%
movies['budget']=movies['budget']/1000000
movies['gross']=movies['gross']/1000000

# %%
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# Find the movies with highest profit 
# 1 create a new column called profit which contains the difference of the two columns gross and budget.
#extract the top ten profiting movies in descending order and store them in a new dataframe .top 10

# %%
movies['profit']= movies['gross'] - movies['budget']
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
top10 =movies.sort_values(by='profit',ascending=False).head(10)
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# # Drop duplicate value

# %%
#after finding the top 10 profiting movies.i might have notice the duplicate valuesso, it seems like the datafarme has duplicate values as wll.Drop the duplicate value from the dataframe and repeat subtask 3.2.

# %%
movies.drop_duplicates(keep='first',inplace=True)

# %%
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
#checkpoint: i might spot two movies directed by james Cameron in the list

# %% [markdown]
# # Find imdb Top 250
# 1.create a new dataframe imdb_top_250 and store the top 250 movies with the highest ImDB Rating (corresponding to the column imdb_score) Also make sure that for all of these movies. the num_voted_user to greater than 25,000 Also add a rank column containing the values 1 to 250 indicating the ranks of the corresponding films.
# 2.Extract the movies in the IMDb_Top_250 dataframe which are not in the english language and store them in a new dataframe named Top_Forigen_lang_film

# %%
imdb_Top_250=movies[movies['num_voted_users'] > 25000].sort_values(by='imdb_score',ascending=False).head(250)
imdb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 66       Christopher Nolan                   645.0  533.316061
# 2837  Francis Ford Coppola                   149.0   57.300000
# 339          Peter Jackson                   328.0  377.019252
# ...                    ...                     ...         ...
# 69             Jon Favreau                   486.0  318.298180
# 75              Doug Liman                   585.0  100.189501
# 3510           Yash Chopra                    29.0    2.921738
# 99           Peter Jackson                   645.0  303.001229
# 3677  Christophe Barratier                   112.0    3.629758
#
#                               genres           actor_1_name  \
# 1937                     Crime|Drama         Morgan Freeman
# 3466                     Crime|Drama              Al Pacino
# ...

# %%
imdb_Top_250['Rank']= imdb_Top_250['imdb_score'].rank(method='first',ascending=False)
imdb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 66       Christopher Nolan                   645.0  533.316061
# 2837  Francis Ford Coppola                   149.0   57.300000
# 339          Peter Jackson                   328.0  377.019252
# ...                    ...                     ...         ...
# 69             Jon Favreau                   486.0  318.298180
# 75              Doug Liman                   585.0  100.189501
# 3510           Yash Chopra                    29.0    2.921738
# 99           Peter Jackson                   645.0  303.001229
# 3677  Christophe Barratier                   112.0    3.629758
#
#                               genres           actor_1_name  \
# 1937                     Crime|Drama         Morgan Freeman
# 3466                     Crime|Drama              Al Pacino
# ...

# %%
imdb_Top_250[imdb_Top_250['language']!='English']
imdb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 66       Christopher Nolan                   645.0  533.316061
# 2837  Francis Ford Coppola                   149.0   57.300000
# 339          Peter Jackson                   328.0  377.019252
# ...                    ...                     ...         ...
# 69             Jon Favreau                   486.0  318.298180
# 75              Doug Liman                   585.0  100.189501
# 3510           Yash Chopra                    29.0    2.921738
# 99           Peter Jackson                   645.0  303.001229
# 3677  Christophe Barratier                   112.0    3.629758
#
#                               genres           actor_1_name  \
# 1937                     Crime|Drama         Morgan Freeman
# 3466                     Crime|Drama              Al Pacino
# ...

# %%
# spot veerzara in the dataframe?
#Group the datafarme using the director_name column
#find out the top 10 directors whom the mean of imdb_score is the highest and store them in a new dataframe top10director.

# %%
#extract top 10 directors 
movies.groupby('director_name').imdb_score.mean().sort_values(ascending=False).head(10)
# Out:
# director_name
# Charles Chaplin          8.600000
# Tony Kaye                8.600000
# Alfred Hitchcock         8.500000
# Ron Fricke               8.500000
# Damien Chazelle          8.500000
# Majid Majidi             8.500000
# Sergio Leone             8.433333
# Christopher Nolan        8.425000
# S.S. Rajamouli           8.400000
# Marius A. Markevicius    8.400000
# Name: imdb_score, dtype: float64

# %% [markdown]
# # Find popular generes

# %%
#youn might have noticed the generes column inthe  dataframe with all the generes of the moies seperated by apipe(i) by out alll the movies generes the first two are most signinificant for any film 
#extract the first two generes column an d store them in two new columns genere_1 and genere_2 some of the movies might have 
# only one genere in such cases extract the single genere into both the columnsi.e for such movies the genere_2 will be the same as genere_1 
#groupm the dataframe using genere_1 as the primary column and genere_2 as the secondury column
#find out the  5 most popular combo of generes by finding the mean of the gross values using the gross column and store them in a new dataframe name pop genere

# %%
movies.genres.str.split('|',expand=True).iloc[:,0:2]
# Out:
#                 0          1
# 0          Action  Adventure
# 1          Action  Adventure
# 2          Action  Adventure
# 3          Action   Thriller
# 5          Action  Adventure
# ...           ...        ...
# 5033        Drama     Sci-Fi
# 5034     Thriller       None
# 5035       Action      Crime
# 5037       Comedy      Drama
# 5042  Documentary       None
#
# [3857 rows x 2 columns]

# %%
Tempgenere = movies.genres.str.split('|',expand=True).iloc[:,0:2]
Tempgenere.columns=['genre_1','genre_2']
Tempgenere.genre_2.fillna(Tempgenere.genre_1,inplace=True)
Tempgenere
# Out:
#           genre_1      genre_2
# 0          Action    Adventure
# 1          Action    Adventure
# 2          Action    Adventure
# 3          Action     Thriller
# 5          Action    Adventure
# ...           ...          ...
# 5033        Drama       Sci-Fi
# 5034     Thriller     Thriller
# 5035       Action        Crime
# 5037       Comedy        Drama
# 5042  Documentary  Documentary
#
# [3857 rows x 2 columns]

# %%
movies=pd.concat([movies,Tempgenere],axis=1)
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies.groupby(['genre_1','genre_2']).gross.mean().sort_values(ascending=False).head(5)
# Out:
# genre_1    genre_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Family       118.919540
#            Animation    116.998550
# Action     Adventure    109.595465
# Name: gross, dtype: float64

# %% [markdown]
# # Find the critic-Favorite and audience-favorite and audience-favorite actors

# %%
#create three new dataframes namely Meryl_streep, Leo_Caprico and Brad_Fitt Which contains the movies in which the actors. 'meryl Streep', 'Leonardo Dicaprio' and 'Brad Pitt' are the lead actors use only the actors1__name
#column for extraction.also, make sure that you use the name 'Meryl streep','Leonardo Dicaprio'and 'Brad pit for' the said extraction
#append the rows of these Dartaframes the store them in the new dataframe named combined 
#Group the combined dataframe using the actor_1_name column
#Find the mean of the num_critic_for_reviews and identify the actors which have the highest mean

# %%
#movies.memory_usage()
#movies.empty

# %%
Meryl_streep = movies[movies['actor_1_name']=='Meryl Streep']
Leo_caprico = movies[movies['actor_1_name']=='Leonardo dicaprio']
Brad_pitt = movies[movies['actor_1_name']=='Brad pitt']

# %%
combined = Meryl_streep.append((Leo_caprico,Brad_pitt))
combined
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 410     Nancy Meyers                   187.0  112.703470
# 1106   Curtis Hanson                    42.0   46.815748
# 1204     Nora Ephron                   252.0   94.125426
# 1408   David Frankel                   208.0  124.732962
# 1483  Robert Redford                   227.0   14.998070
# 1575  Sydney Pollack                    66.0   87.100000
# 1618   David Frankel                   234.0   63.536011
# 1674   Carl Franklin                    64.0   23.209440
# 1925  Stephen Daldry                   174.0   41.597830
# 2781  Phyllida Lloyd                   331.0   29.959436
# 3135   Robert Altman                   211.0   20.338609
#
#                                genres  actor_1_name  \
# 410              Comedy|Drama|Romance  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1408             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
num_critic_for_reviews and num_user_for_review

# %%
combined.groupby('actor_1_name').num_critic_for_reviews.mean()
# Out:
# actor_1_name
# Meryl Streep    181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
combined.num_user_for_reviews = combined.num_user_for_reviews.astype('int')
combined.num_user_for_reviews
# Out:
# 410     214
# 1106     69
# 1204    277
# 1408    631
# 1483    298
# 1575    200
# 1618    178
# 1674    112
# 1925    660
# 2781    350
# 3135    280
# Name: num_user_for_reviews, dtype: int32

# %%
combined.groupby('actor_1_name').num_user_for_reviews.mean()
# Out:
# actor_1_name
# Meryl Streep    297.181818
# Name: num_user_for_reviews, dtype: float64

# %%
combined.groupby('actor_1_name')[['num_critic_for_reviews','num_user_for_reviews']].mean()
# Out:
#               num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Meryl Streep              181.454545            297.181818

# %%
# Leonardo has aced both the list
